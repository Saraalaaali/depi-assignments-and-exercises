# %% [markdown]
# # Welcome!

# %% [markdown]
# #### Pandas: Intro Practice Problems
#
# In this homework, you're going to write code for a few problems.
#
# You'll be practicing these programming concepts we've covered in class:
# * Reading data sets into Pandas.
# * Filtering, manipulating, and sorting data sets.
# * Basic exploratory data analysis with Pandas.

# %% [markdown]
# #### #1. Import Pandas with an alias of `pd`.

# %%
import pandas as pd

# %% [markdown]
# #### #2. Read in the NBA players `csv` into a variable called `nba_df`.

# %% [markdown]
# This is a data set of NBA players from 2015. The filename is `NBA_players_2015.csv`.

# %%
nba_df=pd.read_csv('NBA_players_2015 1.csv')

# %% [markdown]
# #### #3. Look at the first five rows of the data set.

# %%
print(nba_df.head())
# Out:
#    season_end         player pos  age bref_team_id   g  gs    mp   fg   fga  \
# 0        2015     Quincy Acy   F   24          NYK  52  21  19.2  2.2   4.6
# 1        2015   Jordan Adams   G   20          MEM  18   0   7.3  1.0   2.1
# 2        2015   Steven Adams   C   21          OKC  51  50  24.2  3.0   5.5
# 3        2015    Jeff Adrien   F   28          MIN  17   0  12.6  1.1   2.6
# 4        2015  Arron Afflalo   G   29          TOT  60  54  32.5  5.0  11.8
#
#    ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
#
# [5 rows x 49 columns]

# %% [markdown]
# #### #4. Check out the shape of the data set.

# %%
print(nba_df.shape)
# Out:
# (478, 49)

# %% [markdown]
# #### #5. Run some summary stats on the data set with the `describe()` function.

# %%
print(nba_df.describe())
# Out:
#        season_end         age           g          gs          mp          fg  \
# count       478.0  478.000000  478.000000  478.000000  478.000000  478.000000
# mean       2015.0   26.573222   42.104603   19.874477   20.045607    3.018201
# std           0.0    4.219585   18.950602   22.170034    9.313441    2.052790
# min        2015.0   19.000000    1.000000    0.000000    0.700000    0.000000
# 25%        2015.0   23.000000   27.000000    0.000000   12.600000    1.425000
# 50%        2015.0   26.000000   47.000000   10.500000   19.850000    2.700000
# 75%        2015.0   29.000000   59.000000   39.000000   28.175000    4.275000
# max        2015.0   38.000000   66.000000   66.000000   38.900000    9.500000
#
#               fga         fg_         x3p        x3pa  ...        TOV%  \
# count  478.000000  478.000000  478.000000  478.000000  ...  478.000000
# mean     6.847699    0.429230    0.630544    1.855649  ...   13.424268
# std      4.386828    0.111007    0.665808    1.790564  ...    6.559989
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      3.400000    0.391000    0.000000    0.100000  ...   10.000000
# 50%      5.900000    0.432000    0.450000    1.400000  ...   12.900000
# 75%      9.600000    0.481750    1.000000    3.075000  ...   15.900000
# max     21.400000    1.000000    3.400000    8.000000  ...  100.000000
#
#              USG%         OWS         DWS          WS       WS/48        OBPM  \
# count  478.000000  478.000000  478.000000  478.000000  478.000000  478.000000
# mean    18.915272    1.055858    0.971339    2.027197    0.073575   -1.396862
# std      5.493491    1.589667    0.876932    2.243138    0.133530    4.251216
# min      0.000000   -2.100000   -0.100000   -0.800000   -1.059000  -36.800000
# 25%     14.800000    0.000000    0.200000    0.300000    0.040250   -2.800000
# 50%     18.400000    0.600000    0.800000    1.400000    0.082500   -1.000000
# 75%     21.900000    1.600000    1.500000    3.000000    0.123000    0.500000
# max     45.900000    9.500000    4.300000   13.000000    1.489000   28.300000
#
#              DBPM         BPM        VORP
# count  478.000000  478.000000  478.000000
# mean    -0.495816   -1.892678    0.485983
# std      2.299572    5.116001    1.013097
# min    -13.500000  -50.300000   -1.000000
# 25%     -1.600000   -3.300000   -0.100000
# 50%     -0.500000   -1.300000    0.100000
# 75%      0.875000    0.500000    0.700000
# max      6.500000   15.100000    6.200000
#
# [8 rows x 46 columns]

# %% [markdown]
# #### #6. Sort the data set in on the `players` column in alphabetical order.

# %%
nba_df_sorted = nba_df.sort_values(by='player', ascending=True)
print(nba_df_sorted.head())
# Out:
#      season_end         player pos  age bref_team_id   g  gs    mp   fg   fga  \
# 359        2015     A.J. Price   G   28          TOT  21   0  13.3  2.3   5.9
# 60         2015   Aaron Brooks   G   30          CHI  65   9  21.0  3.9   9.3
# 166        2015   Aaron Gordon   F   19          ORL  30   6  15.2  1.9   3.8
# 348        2015  Adreian Payne   F   23          TOT  12   3  19.7  2.3   6.1
# 212        2015     Al Horford   C   28          ATL  60  60  30.8  6.8  12.6
#
#      ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 359  ...   8.9  23.6  0.2  0.2  0.4  0.072   0.5  -2.8 -2.4   0.0
# 60   ...  15.5  25.7  1.1  1.0  2.1  0.073   0.7  -2.8 -2.1   0.0
# 166  ...  17.0  15.9  0.3  0.3  0.6  0.066  -2.5  -0.5 -3.1  -0.1
# 348  ...  13.6  17.7 -0.3  0.1 -0.1 -0.024  -5.8  -2.5 -8.3  -0.4
# 212  ...   9.1  22.1  4.6  3.0  7.5  0.195   1.7   2.7  4.5   3.0
#
# [5 rows x 49 columns]

# %% [markdown]
# #### #7. Filter the data set. Create three sub DataFrames from the `position` column for `G`, `F`, and `C`.

# %%
g_df = nba_df[nba_df['pos'] == 'G']
f_df = nba_df[nba_df['pos'] == 'F']
c_df = nba_df[nba_df['pos'] == 'C']

# %% [markdown]
# #### #8.  Run `describe()` on these new DataFrames. Compare the mean field goals (the `fg` column) between positions.

# %%
print("Guards (G) Description:")
print(g_df.describe())

print("\nForwards (F) Description:")
print(f_df.describe())

print("\nCenters (C) Description:")
print(c_df.describe())

# Compare the mean field goals (fg column)
print("\nMean Field Goals Comparison:")
print("Guards:", g_df['fg'].mean())
print("Forwards:", f_df['fg'].mean())
print("Centers:", c_df['fg'].mean())
# Out:
# Guards (G) Description:
#        season_end         age           g          gs          mp          fg  \
# count       200.0  200.000000  200.000000  200.000000  200.000000  200.000000
# mean       2015.0   26.140000   42.365000   19.475000   21.308000    3.200000
# std           0.0    4.193846   18.939782   22.103216    9.463622    2.042267
# min        2015.0   19.000000    1.000000    0.000000    1.000000    0.000000
# 25%        2015.0   23.000000   28.750000    0.000000   13.375000    1.600000
# 50%        2015.0   25.500000   47.000000    9.500000   22.150000    2.900000
# 75%        2015.0   29.000000   60.000000   36.000000   29.825000    4.500000
# max        2015.0   38.000000   66.000000   66.000000   38.900000    9.300000
#
#               fga         fg_         x3p        x3pa  ...        TOV%  \
# count  200.000000  200.000000  200.000000  200.000000  ...  200.000000
# mean     7.736500    0.391610    0.928500    2.712000  ...   13.732500
# std      4.500555    0.088114    0.684089    1.713487  ...    5.518393
# min      1.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      4.075000    0.370750    0.400000    1.400000  ...   10.275000
# 50%      7.000000    0.406000    0.900000    2.500000  ...   13.550000
# 75%     11.100000    0.435250    1.400000    3.800000  ...   16.300000
# max     21.400000    0.523000    3.400000    8.000000  ...   45.000000
#
#              USG%         OWS         DWS          WS       WS/48        OBPM  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    20.330500    1.030500    0.849500    1.881500    0.047755   -1.019000
# std      5.378434    1.780441    0.795275    2.351949    0.135217    4.654218
# min      7.600000   -2.100000   -0.100000   -0.800000   -1.059000  -36.800000
# 25%     16.775000    0.000000    0.200000    0.200000    0.023750   -2.000000
# 50%     19.900000    0.500000    0.700000    1.100000    0.067500   -0.500000
# 75%     23.400000    1.500000    1.200000    2.700000    0.109250    0.900000
# max     45.900000    9.500000    3.500000   13.000000    0.289000    9.400000
#
#              DBPM         BPM        VORP
# count  200.000000  200.000000  200.000000
# mean    -1.310500   -2.329000    0.473000
# std      2.022993    5.821849    1.136056
# min    -13.500000  -50.300000   -0.900000
# 25%     -2.300000   -3.525000   -0.100000
# 50%     -1.300000   -1.800000    0.000000
# 75%     -0.100000    0.200000    0.600000
# max      6.500000   12.000000    6.200000
#
# [8 rows x 46 columns]
#
# Forwards (F) Description:
#        season_end         age           g          gs          mp          fg  \
# count       199.0  199.000000  199.000000  199.000000  199.000000  199.000000
# mean       2015.0   26.934673   41.879397   18.788945   19.141709    2.846734
# std           0.0    4.377485   19.032283   22.174826    9.204145    2.055217
# min        2015.0   19.000000    1.000000    0.000000    0.700000    0.000000
# 25%        2015.0   23.500000   26.500000    0.000000   11.550000    1.300000
# 50%        2015.0   26.000000   48.000000    7.000000   18.400000    2.300000
# 75%        2015.0   29.500000   58.000000   39.500000   27.450000    4.000000
# max        2015.0   38.000000   66.000000   65.000000   36.200000    9.500000
#
#               fga         fg_         x3p        x3pa  ...        TOV%  \
# count  199.000000  199.000000  199.000000  199.000000  ...  199.000000
# mean     6.321608    0.440688    0.558291    1.657789  ...   12.425628
# std      4.247767    0.113317    0.595284    1.658960  ...    7.543102
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      3.100000    0.398000    0.000000    0.100000  ...    9.500000
# 50%      5.200000    0.444000    0.400000    1.200000  ...   11.700000
# 75%      8.700000    0.488000    1.000000    2.850000  ...   14.050000
# max     20.200000    1.000000    2.400000    6.900000  ...  100.000000
#
#              USG%         OWS         DWS          WS      WS/48        OBPM  \
# count  199.000000  199.000000  199.000000  199.000000  199.00000  199.000000
# mean    17.953266    1.017085    0.987437    2.001508    0.09007   -1.370854
# std      5.274225    1.442959    0.888702    2.118306    0.13492    3.926709
# min      7.800000   -1.300000    0.000000   -0.400000   -0.33700  -25.500000
# 25%     14.150000    0.000000    0.300000    0.300000    0.04950   -2.950000
# 50%     17.700000    0.500000    0.800000    1.400000    0.08900   -1.100000
# 75%     20.850000    1.550000    1.500000    3.100000    0.12500    0.200000
# max     45.900000    8.100000    4.300000   11.100000    1.48900   28.300000
#
#              DBPM         BPM        VORP
# count  199.000000  199.000000  199.000000
# mean    -0.251256   -1.621608    0.487940
# std      2.340829    4.454924    0.914781
# min    -13.300000  -35.100000   -1.000000
# 25%     -1.200000   -3.100000   -0.100000
# 50%     -0.100000   -1.000000    0.200000
# 75%      0.900000    0.450000    0.800000
# max      4.600000   15.100000    4.600000
#
# [8 rows x 46 columns]
#
# Centers (C) Description:
#        season_end        age          g         gs         mp         fg  \
# count        79.0  79.000000  79.000000  79.000000  79.000000  79.000000
# mean       2015.0  26.759494  42.012658  23.620253  19.126582   2.989873
# std           0.0   3.810294  19.005056  22.214747   8.937629   2.060595
# min        2015.0  20.000000   2.000000   0.000000   2.800000   0.000000
# 25%        2015.0  24.000000  29.500000   2.500000  12.700000   1.500000
# 50%        2015.0  26.000000  46.000000  18.000000  19.200000   2.800000
# 75%        2015.0  29.500000  58.500000  43.500000  25.900000   4.100000
# max        2015.0  37.000000  65.000000  64.000000  35.400000   8.600000
#
#              fga        fg_        x3p       x3pa  ...       TOV%       USG%  \
# count  79.000000  79.000000  79.000000  79.000000  ...  79.000000  79.000000
# mean    5.922785   0.495608   0.058228   0.186076  ...  15.159494  17.755696
# std     4.075409   0.120526   0.211592   0.571264  ...   5.933035   5.592709
# min     0.000000   0.000000   0.000000   0.000000  ...   0.000000   0.000000
# 25%     2.850000   0.460500   0.000000   0.000000  ...  12.150000  13.650000
# 50%     5.300000   0.505000   0.000000   0.000000  ...  15.300000  17.900000
# 75%     7.600000   0.551000   0.000000   0.100000  ...  17.550000  21.150000
# max    17.400000   0.857000   1.400000   3.800000  ...  43.200000  35.700000
#
#              OWS        DWS         WS      WS/48       OBPM       DBPM  \
# count  79.000000  79.000000  79.000000  79.000000  79.000000  79.000000
# mean    1.217722   1.239241   2.460759   0.097392  -2.418987   0.950633
# std     1.431402   0.986371   2.240674   0.114917   3.832823   2.003578
# min    -1.000000   0.000000  -0.300000  -0.738000 -28.000000  -5.700000
# 25%     0.200000   0.300000   0.600000   0.076000  -3.250000  -0.300000
# 50%     0.800000   1.200000   2.100000   0.115000  -1.900000   1.100000
# 75%     1.850000   1.800000   3.650000   0.146000  -0.200000   2.300000
# max     6.100000   4.100000   9.900000   0.231000   2.100000   5.500000
#
#              BPM       VORP
# count  79.000000  79.000000
# mean   -1.470886   0.513924
# std     4.727881   0.926495
# min   -28.800000  -0.600000
# 25%    -2.700000  -0.100000
# 50%    -0.900000   0.200000
# 75%     0.750000   0.700000
# max     5.800000   3.600000
#
# [8 rows x 46 columns]
#
# Mean Field Goals Comparison:
# Guards: 3.2
# Forwards: 2.8467336683417086
# Centers: 2.9898734177215194

# %% [markdown]
# The end!

# %% [markdown]
# #### Great job!
